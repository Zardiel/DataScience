# %% [markdown]
# # Игра угадай число

# %% [markdown]
# ## Игра угодайчисло V3 менее чем за 20 попыток

# %%
from game_V3 import score_game
from game_V3 import game_core_v3

# %% [markdown]
# ## Игра угадай число V2

# %%
from game_V2 import random_predict
from game_V2 import score_game as score_game_v2

# %% [markdown]
# ## Угадываем рандомно

# %%
score_game(game_core_v3) # Запускаем функции
# Out:
# Ваш алгоритм угадывает число в среднем за: 14 попытки

# %%
score_game_v2(random_predict) # Запускаем функции
# Out:
# Ваш алгоритм угадывает число в среднем за: 101 попыток
# 101
